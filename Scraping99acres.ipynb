# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import time 
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# ### implementing a page wait function to handle page loading

# %%
def page_wait(driver,wait):
    title = driver.title
    try:
        wait.until(
            #it expects a function that should take driver insatance as input
            lambda d : d.execute_script("return document.readyState") == "complete"
        )
    except :
        print(f"The webpage {title} loading is unsuccesful.\n")
    else:
        print(f"The webpage {title} was loaded succesfully\n")

# %% [markdown]
# ### The scraping script

# %%
# Chrome options to bypass security mechanisms
chrome_options = Options()
chrome_options.add_argument("--disable-http2")
chrome_options.add_argument("--incognito")
chrome_options.add_argument("--disable-blink-features=AutomationControlled")
chrome_options.add_argument("--ignore-certificate-errors")
chrome_options.add_argument("--enable-features=NetworkServiceInProcess")
chrome_options.add_argument("--disable-features=NetworkService")
chrome_options.add_argument(
    "user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36"
)

driver = webdriver.Chrome(options=chrome_options)
driver.maximize_window()

# Explicit waits
wait = WebDriverWait(driver, 5)

# Accessing the target webpage
url = "https://www.99acres.com"
driver.get(url)
page_wait(driver, wait)

# Finding the location search bar
try:
    search_bar = wait.until(
        EC.presence_of_element_located((By.XPATH, '//*[@id="keyword2"]'))
    )
except:
    print("Search bar wasn't found in time frame\n")
else:
    search_bar.send_keys("Mysore")

# Selecting Mysore
try:
    mysore = wait.until(
        EC.element_to_be_clickable((By.XPATH, '//*[@id="0"]'))
    )
except:
    print("Mysore option wasn't found in time frame\n")
else:
    mysore.click()
    time.sleep(2)

# Hitting enter
try:
    search_btn = wait.until(
        EC.element_to_be_clickable((By.XPATH, '//*[@id="searchform_search_btn"]'))
    )
except:
    print("Search button could not be clicked in time frame")
else:
    search_btn.click()
    page_wait(driver, wait)
    time.sleep(2)

# Adjusting budget slider to only consider properties worth less than 5 crores
try:
    slider = wait.until(
        EC.element_to_be_clickable((By.XPATH, '//*[@id="budgetLeftFilter_max_node"]'))
    )
except:
    print("Budget slider wasn't loaded in time frame")
else:
    actions = ActionChains(driver)
    (
        actions
        .click_and_hold(slider)
        .move_by_offset(-72, 0)
        .release()
        .perform()
    )
    time.sleep(2)

# Filter results to include only ready-to-move properties
try:
    ready = wait.until(
        EC.element_to_be_clickable((By.XPATH, '//*[@id="app"]/div/div/div[4]/div[3]/div[1]/div[3]/section/div/div/div/div/div[1]/div/div[4]'))
    )
except:
    print("Ready button wasn't loaded in time frame")
else:
    ready.click()
    time.sleep(1)

# Navigate and extract the data of properties
data = []
page_count = 0

while True:
    page_count += 1
    try:
        rows = driver.find_elements(By.CLASS_NAME, "tupleNew__contentWrap")
        for row in rows:
            try:
                name = row.find_element(By.CLASS_NAME, "tupleNew__headingNrera").text
            except:
                name = np.nan

            try:
                location = row.find_element(By.CLASS_NAME, "tupleNew__propType").text
            except:
                location = np.nan

            try:
                price = row.find_element(By.CLASS_NAME, "tupleNew__priceValWrap").text
            except:
                price = np.nan

            try:
                elements = row.find_elements(By.CLASS_NAME, "tupleNew__area1Type")
            except:
                area, bhk = np.nan, np.nan
            else:
                area, bhk = [ele.text for ele in elements]

            property = {
                "name": name,
                "location": location,
                "price": price,
                "area": area,
                "bhk": bhk
            }
            data.append(property)

        next_page = wait.until(EC.presence_of_element_located((By.XPATH, "//a[normalize-space()='Next Page >']")))
        driver.execute_script("arguments[0].scrollIntoView();", next_page)
        time.sleep(2)
        driver.execute_script("arguments[0].click();", next_page)
        page_wait(driver, wait)

    except StaleElementReferenceException:
        print("Stale element encountered. Retrying...")
        time.sleep(1)
        continue
    except NoSuchElementException:
        print(f"Next Page button not found. No more pages or site changed. {page_count} pages scrolled")
        break
    except Exception as e:
        print("Unexpected error:", e)
        time.sleep(1)
        break
# Out:
# Stale element encountered. Retrying...
# Stale element encountered. Retrying...
# Stale element encountered. Retrying...
# Unexpected error: Message:
# Stacktrace:
# 	GetHandleVerifier [0x00007FF62AE7FE65+26629]
# 	(No symbol) [0x00007FF62ADE6030]
# 	(No symbol) [0x00007FF62AC7931A]
# 	(No symbol) [0x00007FF62ACCF8E7]
# 	(No symbol) [0x00007FF62ACCFB1C]
# 	(No symbol) [0x00007FF62AD234A7]
# 	(No symbol) [0x00007FF62ACF7AEF]
# 	(No symbol) [0x00007FF62AD20169]
# 	(No symbol) [0x00007FF62ACF7883]
# 	(No symbol) [0x00007FF62ACC0550]
# 	(No symbol) [0x00007FF62ACC1803]
# 	GetHandleVerifier [0x00007FF62B1D72DD+3529853]
# 	GetHandleVerifier [0x00007FF62B1EDA42+3621858]
# 	GetHandleVerifier [0x00007FF62B1E24F3+3575443]
# 	GetHandleVerifier [0x00007FF62AF4B79A+860474]
# 	(No symbol) [0x00007FF62ADF08AF]
# 	(No symbol) [0x00007FF62ADECBE4]
# 	(No symbol) [0x00007FF62ADECD86]
# 	(No symbol) [0x00007FF62ADDC2E9]
# 	BaseThreadInitThunk [0x00007FFEC42CE8D7+23]
# 	RtlUserThreadStart [0x00007FFEC4A1BF6C+44]

# %% [markdown]
# ### The scraped data

# %%
data
# Out:
# [{'name': 'Rai Dream City',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹17 - 41.25 Lac',
#   'area': '581 - 1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'GSS Yogic Village',
#   'location': 'Residential land / Plot in Jayapura, Mysore',
#   'price': '₹12.85 - 43.61 Lac',
#   'area': '680 - 2,560 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lalithadripura, Mysore',
#   'location': 'Residential land / Plot in Lalithadripura, Mysore',
#   'price': '₹74 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nestwell Starling Nest',
#   'location': '3 BHK Flat in Vishweshwara Nagar , Mysore',
#   'price': '₹90 Lac',
#   'area': '1,420 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Vidyaranyapura, Mysore',
#   'location': '4 Bedroom House in Vidyaranyapura, Mysore',
#   'price': '₹2.59 Cr',
#   'area': '2,587 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Madagalli, Kalyaninagar, Mysore',
#   'location': 'Residential land / Plot in Madagalli, Kalyaninagar, Mysore',
#   'price': '₹1.57 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'E and F Block, Mysore',
#   'location': 'Residential land / Plot in E and F Block, Mysore',
#   'price': '₹2.28 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal 2nd Stage, Mysore',
#   'location': '10 Bedroom House in Hebbal 2nd Stage, Mysore',
#   'price': '₹2.3 Cr',
#   'area': '3,900 sqft',
#   'bhk': '10 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': '3 Bedroom House in Roopa Nagar, Mysore',
#   'price': '₹3.6 Cr',
#   'area': '2,400 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.32 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Choranahalli, Mysore',
#   'location': '3 Bedroom House in Choranahalli, Mysore',
#   'price': '₹75 Lac',
#   'area': '600 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Zuari Park View',
#   'location': 'Residential land / Plot in Kesare, Mysore',
#   'price': '₹55 Lac',
#   'area': '1,450 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'BEML 3RD Stage Annexure 5',
#   'location': 'Residential land / Plot in Mandakalli, Mysore',
#   'price': '₹65 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Sun city homes pvt ltd',
#   'location': 'Residential land / Plot in sun city homes, Mysore',
#   'price': '₹70 Lac',
#   'area': '4,800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'navami enclave',
#   'location': '3 Bedroom House in Alanahalli, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹56 Lac',
#   'area': '2,368 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bilikere, Mysore',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Rishabh Prarthana',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹20.25 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹20.4 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Aikyas Saptagiri Enclave',
#   'location': 'Residential land / Plot in Mananthavadi Road, Mysore',
#   'price': '₹36 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Dattagalli 3rd Stage, Mysore',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹72.65 Lac',
#   'area': '1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '3,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Rai Dream City',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹17 - 41.25 Lac',
#   'area': '581 - 1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'GSS Yogic Village',
#   'location': 'Residential land / Plot in Jayapura, Mysore',
#   'price': '₹12.85 - 43.61 Lac',
#   'area': '680 - 2,560 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lalithadripura, Mysore',
#   'location': 'Residential land / Plot in Lalithadripura, Mysore',
#   'price': '₹74 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nestwell Starling Nest',
#   'location': '3 BHK Flat in Vishweshwara Nagar , Mysore',
#   'price': '₹90 Lac',
#   'area': '1,420 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Vidyaranyapura, Mysore',
#   'location': '4 Bedroom House in Vidyaranyapura, Mysore',
#   'price': '₹2.59 Cr',
#   'area': '2,587 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Madagalli, Kalyaninagar, Mysore',
#   'location': 'Residential land / Plot in Madagalli, Kalyaninagar, Mysore',
#   'price': '₹1.57 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'E and F Block, Mysore',
#   'location': 'Residential land / Plot in E and F Block, Mysore',
#   'price': '₹2.28 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal 2nd Stage, Mysore',
#   'location': '10 Bedroom House in Hebbal 2nd Stage, Mysore',
#   'price': '₹2.3 Cr',
#   'area': '3,900 sqft',
#   'bhk': '10 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': '3 Bedroom House in Roopa Nagar, Mysore',
#   'price': '₹3.6 Cr',
#   'area': '2,400 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.32 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Choranahalli, Mysore',
#   'location': '3 Bedroom House in Choranahalli, Mysore',
#   'price': '₹75 Lac',
#   'area': '600 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Zuari Park View',
#   'location': 'Residential land / Plot in Kesare, Mysore',
#   'price': '₹55 Lac',
#   'area': '1,450 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'BEML 3RD Stage Annexure 5',
#   'location': 'Residential land / Plot in Mandakalli, Mysore',
#   'price': '₹65 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Sun city homes pvt ltd',
#   'location': 'Residential land / Plot in sun city homes, Mysore',
#   'price': '₹70 Lac',
#   'area': '4,800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'navami enclave',
#   'location': '3 Bedroom House in Alanahalli, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹56 Lac',
#   'area': '2,368 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bilikere, Mysore',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Rishabh Prarthana',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹20.25 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹20.4 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Aikyas Saptagiri Enclave',
#   'location': 'Residential land / Plot in Mananthavadi Road, Mysore',
#   'price': '₹36 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Dattagalli 3rd Stage, Mysore',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹72.65 Lac',
#   'area': '1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '3,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '3,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'YashwanthEnlcave',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹69.11 Lac',
#   'area': '1,304 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Vinyas Silicon Valley',
#   'location': 'Residential land / Plot in Basthipura, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Beerihundi, Mysore',
#   'location': 'Residential land / Plot in Beerihundi, Mysore',
#   'price': '₹31.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹60 Lac',
#   'area': '600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹75 Lac',
#   'area': '750 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bank Employees Colony, Mysore',
#   'location': 'Residential land / Plot in Bank Employees Colony, Mysore',
#   'price': '₹85 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '3rd Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹2.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Emerald Enclave., Mysore',
#   'location': 'Residential land / Plot in Emerald Enclave., Mysore',
#   'price': '₹2.8 Cr',
#   'area': '9,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Deepa Suvarna Nagara',
#   'location': 'Residential land / Plot in Gohalli, Mysore',
#   'price': '₹68 Lac',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Mahadevpura Road, Mysore',
#   'location': 'Residential land / Plot in Mahadevpura Road, Mysore',
#   'price': '₹25.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹1.35 Cr',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹4 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srirampura, Mysore',
#   'location': 'Residential land / Plot in Srirampura, Mysore',
#   'price': '₹69 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Kuvempunagar, Mysore',
#   'location': 'Residential land / Plot in Kuvempunagar, Mysore',
#   'price': '₹2.18 Cr',
#   'area': '1,980 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Gohalli, Mysore',
#   'location': 'Residential land / Plot in Gohalli, Mysore',
#   'price': '₹31.2 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'KBL Gardenia',
#   'location': 'Residential land / Plot in Madagalli, Mysore',
#   'price': '₹86 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bilikere, Mysore',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹16.2 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.45 Cr',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Srirampura, Mysore',
#   'location': 'Residential land / Plot in Srirampura, Mysore',
#   'price': '₹51 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Heritage City',
#   'location': 'Residential land / Plot in Uttanahalli, Mysore',
#   'price': '₹72 Lac',
#   'area': '6,534 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 BHK Independent Builder Floor in JP Nagar, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,000 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,500 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Sree Sapthamathrukha Layout, Mysore',
#   'location': 'Residential land / Plot in Sree Sapthamathrukha Layout, Mysore',
#   'price': '₹18 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal, Mysore',
#   'location': 'Residential land / Plot in Hebbal, Mysore',
#   'price': '₹1.25 Cr',
#   'area': '1,300 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'KBL Green wood',
#   'location': 'Residential land / Plot in Jss Layout, Mysore',
#   'price': '₹56 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '3 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹80 Lac',
#   'area': '600 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 Bedroom House in JP Nagar, Mysore',
#   'price': '₹2.5 Cr',
#   'area': '1,800 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '3 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.65 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Dc conversation,DMG Halli',
#   'location': 'Residential land / Plot in Bogadi Road, Mysore',
#   'price': '₹22.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': 'Residential land / Plot in JP Nagar, Mysore',
#   'price': '₹29.5 Lac',
#   'area': '1,163 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '1,475 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '4 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '4 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹85 Lac',
#   'area': '600 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.15 Cr',
#   'area': '1,440 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹90 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '2 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Block I Ramakrishnanagar, Mysore',
#   'location': '3 Bedroom House in Block I Ramakrishnanagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Saijayini Sai Brindavan',
#   'location': '3 BHK Flat in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,707 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Hadinaru, Mysore',
#   'location': 'Residential land / Plot in Hadinaru, Mysore',
#   'price': '₹16 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Subramanya Nagar, Mysore',
#   'location': '2 Bedroom House in Subramanya Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '936 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Vyasti Urbane',
#   'location': 'Residential land / Plot in Vijayanagar, Mysore',
#   'price': '₹77 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nithyanandhasagara Layout Phase 1',
#   'location': 'Residential land / Plot in Huyilalu, Mysore',
#   'price': '₹57 Lac',
#   'area': '2,020 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Rai Dream City',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹17 - 41.25 Lac',
#   'area': '581 - 1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'GSS Yogic Village',
#   'location': 'Residential land / Plot in Jayapura, Mysore',
#   'price': '₹12.85 - 43.61 Lac',
#   'area': '680 - 2,560 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lalithadripura, Mysore',
#   'location': 'Residential land / Plot in Lalithadripura, Mysore',
#   'price': '₹74 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nestwell Starling Nest',
#   'location': '3 BHK Flat in Vishweshwara Nagar , Mysore',
#   'price': '₹90 Lac',
#   'area': '1,420 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Vidyaranyapura, Mysore',
#   'location': '4 Bedroom House in Vidyaranyapura, Mysore',
#   'price': '₹2.59 Cr',
#   'area': '2,587 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Madagalli, Kalyaninagar, Mysore',
#   'location': 'Residential land / Plot in Madagalli, Kalyaninagar, Mysore',
#   'price': '₹1.57 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'E and F Block, Mysore',
#   'location': 'Residential land / Plot in E and F Block, Mysore',
#   'price': '₹2.28 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal 2nd Stage, Mysore',
#   'location': '10 Bedroom House in Hebbal 2nd Stage, Mysore',
#   'price': '₹2.3 Cr',
#   'area': '3,900 sqft',
#   'bhk': '10 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': '3 Bedroom House in Roopa Nagar, Mysore',
#   'price': '₹3.6 Cr',
#   'area': '2,400 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.32 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Choranahalli, Mysore',
#   'location': '3 Bedroom House in Choranahalli, Mysore',
#   'price': '₹75 Lac',
#   'area': '600 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Zuari Park View',
#   'location': 'Residential land / Plot in Kesare, Mysore',
#   'price': '₹55 Lac',
#   'area': '1,450 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'BEML 3RD Stage Annexure 5',
#   'location': 'Residential land / Plot in Mandakalli, Mysore',
#   'price': '₹65 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Sun city homes pvt ltd',
#   'location': 'Residential land / Plot in sun city homes, Mysore',
#   'price': '₹70 Lac',
#   'area': '4,800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'navami enclave',
#   'location': '3 Bedroom House in Alanahalli, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹56 Lac',
#   'area': '2,368 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bilikere, Mysore',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Rishabh Prarthana',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹20.25 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹20.4 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Aikyas Saptagiri Enclave',
#   'location': 'Residential land / Plot in Mananthavadi Road, Mysore',
#   'price': '₹36 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Dattagalli 3rd Stage, Mysore',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹72.65 Lac',
#   'area': '1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '3,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '3,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'YashwanthEnlcave',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹69.11 Lac',
#   'area': '1,304 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Vinyas Silicon Valley',
#   'location': 'Residential land / Plot in Basthipura, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Beerihundi, Mysore',
#   'location': 'Residential land / Plot in Beerihundi, Mysore',
#   'price': '₹31.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹60 Lac',
#   'area': '600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹75 Lac',
#   'area': '750 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bank Employees Colony, Mysore',
#   'location': 'Residential land / Plot in Bank Employees Colony, Mysore',
#   'price': '₹85 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '3rd Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹2.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Emerald Enclave., Mysore',
#   'location': 'Residential land / Plot in Emerald Enclave., Mysore',
#   'price': '₹2.8 Cr',
#   'area': '9,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Deepa Suvarna Nagara',
#   'location': 'Residential land / Plot in Gohalli, Mysore',
#   'price': '₹68 Lac',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Mahadevpura Road, Mysore',
#   'location': 'Residential land / Plot in Mahadevpura Road, Mysore',
#   'price': '₹25.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹1.35 Cr',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹4 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srirampura, Mysore',
#   'location': 'Residential land / Plot in Srirampura, Mysore',
#   'price': '₹69 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Kuvempunagar, Mysore',
#   'location': 'Residential land / Plot in Kuvempunagar, Mysore',
#   'price': '₹2.18 Cr',
#   'area': '1,980 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Gohalli, Mysore',
#   'location': 'Residential land / Plot in Gohalli, Mysore',
#   'price': '₹31.2 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'KBL Gardenia',
#   'location': 'Residential land / Plot in Madagalli, Mysore',
#   'price': '₹86 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bilikere, Mysore',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹16.2 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.45 Cr',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Srirampura, Mysore',
#   'location': 'Residential land / Plot in Srirampura, Mysore',
#   'price': '₹51 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Heritage City',
#   'location': 'Residential land / Plot in Uttanahalli, Mysore',
#   'price': '₹72 Lac',
#   'area': '6,534 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 BHK Independent Builder Floor in JP Nagar, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,000 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,500 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Sree Sapthamathrukha Layout, Mysore',
#   'location': 'Residential land / Plot in Sree Sapthamathrukha Layout, Mysore',
#   'price': '₹18 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal, Mysore',
#   'location': 'Residential land / Plot in Hebbal, Mysore',
#   'price': '₹1.25 Cr',
#   'area': '1,300 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'KBL Green wood',
#   'location': 'Residential land / Plot in Jss Layout, Mysore',
#   'price': '₹56 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '3 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹80 Lac',
#   'area': '600 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 Bedroom House in JP Nagar, Mysore',
#   'price': '₹2.5 Cr',
#   'area': '1,800 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '3 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.65 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Dc conversation,DMG Halli',
#   'location': 'Residential land / Plot in Bogadi Road, Mysore',
#   'price': '₹22.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': 'Residential land / Plot in JP Nagar, Mysore',
#   'price': '₹29.5 Lac',
#   'area': '1,163 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '1,475 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '4 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '4 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹85 Lac',
#   'area': '600 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.15 Cr',
#   'area': '1,440 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹90 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '2 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Block I Ramakrishnanagar, Mysore',
#   'location': '3 Bedroom House in Block I Ramakrishnanagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Saijayini Sai Brindavan',
#   'location': '3 BHK Flat in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,707 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Hadinaru, Mysore',
#   'location': 'Residential land / Plot in Hadinaru, Mysore',
#   'price': '₹16 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Subramanya Nagar, Mysore',
#   'location': '2 Bedroom House in Subramanya Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '936 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Vyasti Urbane',
#   'location': 'Residential land / Plot in Vijayanagar, Mysore',
#   'price': '₹77 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nithyanandhasagara Layout Phase 1',
#   'location': 'Residential land / Plot in Huyilalu, Mysore',
#   'price': '₹57 Lac',
#   'area': '2,020 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'hari vidyalaya',
#   'location': '2 BHK Independent Builder Floor in Bogadi, Mysore',
#   'price': '₹73 Lac',
#   'area': '30 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'ESS Anandhasagara Layout',
#   'location': 'Residential land / Plot in Huyilalu, Mysore',
#   'price': '₹1 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Ilavala Hobli, Mysore',
#   'location': 'Residential land / Plot in Ilavala Hobli, Mysore',
#   'price': '₹19.5 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '4 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Owner Built',
#   'location': '3 Bedroom House in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹3.3 Cr',
#   'area': '2,325 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 BHK Independent Builder Floor in JP Nagar, Mysore',
#   'price': '₹1.95 Cr',
#   'area': '1,750 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Sankalp Gardenia',
#   'location': '2 BHK Flat in Gokulam, Mysore',
#   'price': '₹96 Lac',
#   'area': '1,385 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'KBL Silicon City\n3.6',
#   'location': 'Residential land / Plot in Hebbal, Mysore',
#   'price': '₹47 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Shakthinagar, Mysore',
#   'location': '3 Bedroom House in Shakthinagar, Mysore',
#   'price': '₹2.9 Cr',
#   'area': '5,500 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Close to NPS',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹85 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'K Hemmanahalli, Mysore',
#   'location': 'Residential land / Plot in K Hemmanahalli, Mysore',
#   'price': '₹35 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'hunsur maroad',
#   'location': '2 Bedroom House in Yelwala, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Police Layout, Mysore',
#   'location': '5 Bedroom House in Police Layout, Mysore',
#   'price': '₹1.3 Cr',
#   'area': '1,162 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Karakanahalli, Mysore',
#   'location': 'Residential land / Plot in Karakanahalli, Mysore',
#   'price': '₹1.2 Cr',
#   'area': '4,935 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Block 6',
#   'location': '2 Bedroom House in Sriramapura 2nd Stage, Mysore',
#   'price': '₹2.1 Cr',
#   'area': '1,953 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Shankara Nagar(Gayathri Layout), Dattagalli, 3rd stage, Mysore',
#   'location': 'Residential land / Plot in Shankara Nagar(Gayathri Layout), Dattagalli, 3rd stage, Mysore',
#   'price': '₹72 Lac',
#   'area': '1,470 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'teachers layout',
#   'location': 'Residential land / Plot in Teachers Layout 1st Stage, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '2,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Koppa, Mysore',
#   'location': '5 Bedroom House in Koppa, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '1,500 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Nanjangud Road, Mysore',
#   'location': 'Residential land / Plot in Nanjangud Road, Mysore',
#   'price': '₹1.12 Cr',
#   'area': '60,983 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Vidyaranyapura, Mysore',
#   'location': '3 Bedroom House in Vidyaranyapura, Mysore',
#   'price': '₹1.15 Cr',
#   'area': '900 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Allanahalli Layout, Mysore',
#   'location': 'Residential land / Plot in Allanahalli Layout, Mysore',
#   'price': '₹98 Lac',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Sooru Layout',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹44 Lac',
#   'area': '2,192 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'sun city homes 3 rd phase B Block',
#   'location': 'Residential land / Plot in Nagawala, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RS Naidu Nagar, Mysore',
#   'location': 'Residential land / Plot in RS Naidu Nagar, Mysore',
#   'price': '₹1.89 Cr',
#   'area': '2,700 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srinivasan IPS Nagar',
#   'location': '5 Bedroom House in Police Layout, 3rd stage, IPS Nagar, Mysore',
#   'price': '₹1.3 Cr',
#   'area': '1,162 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Rai Dream City',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹17 - 41.25 Lac',
#   'area': '581 - 1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'GSS Yogic Village',
#   'location': 'Residential land / Plot in Jayapura, Mysore',
#   'price': '₹12.85 - 43.61 Lac',
#   'area': '680 - 2,560 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lalithadripura, Mysore',
#   'location': 'Residential land / Plot in Lalithadripura, Mysore',
#   'price': '₹74 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nestwell Starling Nest',
#   'location': '3 BHK Flat in Vishweshwara Nagar , Mysore',
#   'price': '₹90 Lac',
#   'area': '1,420 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Vidyaranyapura, Mysore',
#   'location': '4 Bedroom House in Vidyaranyapura, Mysore',
#   'price': '₹2.59 Cr',
#   'area': '2,587 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Madagalli, Kalyaninagar, Mysore',
#   'location': 'Residential land / Plot in Madagalli, Kalyaninagar, Mysore',
#   'price': '₹1.57 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'E and F Block, Mysore',
#   'location': 'Residential land / Plot in E and F Block, Mysore',
#   'price': '₹2.28 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal 2nd Stage, Mysore',
#   'location': '10 Bedroom House in Hebbal 2nd Stage, Mysore',
#   'price': '₹2.3 Cr',
#   'area': '3,900 sqft',
#   'bhk': '10 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': '3 Bedroom House in Roopa Nagar, Mysore',
#   'price': '₹3.6 Cr',
#   'area': '2,400 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.32 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Choranahalli, Mysore',
#   'location': '3 Bedroom House in Choranahalli, Mysore',
#   'price': '₹75 Lac',
#   'area': '600 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Zuari Park View',
#   'location': 'Residential land / Plot in Kesare, Mysore',
#   'price': '₹55 Lac',
#   'area': '1,450 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'BEML 3RD Stage Annexure 5',
#   'location': 'Residential land / Plot in Mandakalli, Mysore',
#   'price': '₹65 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Sun city homes pvt ltd',
#   'location': 'Residential land / Plot in sun city homes, Mysore',
#   'price': '₹70 Lac',
#   'area': '4,800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'navami enclave',
#   'location': '3 Bedroom House in Alanahalli, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹56 Lac',
#   'area': '2,368 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bilikere, Mysore',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Rishabh Prarthana',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹20.25 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹20.4 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Thaluru, Mysore',
#   'location': 'Residential land / Plot in Thaluru, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Aikyas Saptagiri Enclave',
#   'location': 'Residential land / Plot in Mananthavadi Road, Mysore',
#   'price': '₹36 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Dattagalli 3rd Stage, Mysore',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹72.65 Lac',
#   'area': '1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '3,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RT Nagar, Mysore',
#   'location': 'Residential land / Plot in RT Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '3,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'YashwanthEnlcave',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹69.11 Lac',
#   'area': '1,304 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Vinyas Silicon Valley',
#   'location': 'Residential land / Plot in Basthipura, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Beerihundi, Mysore',
#   'location': 'Residential land / Plot in Beerihundi, Mysore',
#   'price': '₹31.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹60 Lac',
#   'area': '600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹75 Lac',
#   'area': '750 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bank Employees Colony, Mysore',
#   'location': 'Residential land / Plot in Bank Employees Colony, Mysore',
#   'price': '₹85 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '3rd Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹2.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Emerald Enclave., Mysore',
#   'location': 'Residential land / Plot in Emerald Enclave., Mysore',
#   'price': '₹2.8 Cr',
#   'area': '9,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Deepa Suvarna Nagara',
#   'location': 'Residential land / Plot in Gohalli, Mysore',
#   'price': '₹68 Lac',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Mahadevpura Road, Mysore',
#   'location': 'Residential land / Plot in Mahadevpura Road, Mysore',
#   'price': '₹25.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹1.35 Cr',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹4 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srirampura, Mysore',
#   'location': 'Residential land / Plot in Srirampura, Mysore',
#   'price': '₹69 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Kuvempunagar, Mysore',
#   'location': 'Residential land / Plot in Kuvempunagar, Mysore',
#   'price': '₹2.18 Cr',
#   'area': '1,980 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Gohalli, Mysore',
#   'location': 'Residential land / Plot in Gohalli, Mysore',
#   'price': '₹31.2 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'KBL Gardenia',
#   'location': 'Residential land / Plot in Madagalli, Mysore',
#   'price': '₹86 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bilikere, Mysore',
#   'location': 'Residential land / Plot in Bilikere, Mysore',
#   'price': '₹16.2 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.45 Cr',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Srirampura, Mysore',
#   'location': 'Residential land / Plot in Srirampura, Mysore',
#   'price': '₹51 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Heritage City',
#   'location': 'Residential land / Plot in Uttanahalli, Mysore',
#   'price': '₹72 Lac',
#   'area': '6,534 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 BHK Independent Builder Floor in JP Nagar, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,000 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,500 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Sree Sapthamathrukha Layout, Mysore',
#   'location': 'Residential land / Plot in Sree Sapthamathrukha Layout, Mysore',
#   'price': '₹18 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal, Mysore',
#   'location': 'Residential land / Plot in Hebbal, Mysore',
#   'price': '₹1.25 Cr',
#   'area': '1,300 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'KBL Green wood',
#   'location': 'Residential land / Plot in Jss Layout, Mysore',
#   'price': '₹56 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '3 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹80 Lac',
#   'area': '600 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 Bedroom House in JP Nagar, Mysore',
#   'price': '₹2.5 Cr',
#   'area': '1,800 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '3 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.65 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Dc conversation,DMG Halli',
#   'location': 'Residential land / Plot in Bogadi Road, Mysore',
#   'price': '₹22.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': 'Residential land / Plot in JP Nagar, Mysore',
#   'price': '₹29.5 Lac',
#   'area': '1,163 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '1,475 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '4 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '4 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹85 Lac',
#   'area': '600 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '3 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹1.15 Cr',
#   'area': '1,440 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '2 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹90 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '2 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Block I Ramakrishnanagar, Mysore',
#   'location': '3 Bedroom House in Block I Ramakrishnanagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Saijayini Sai Brindavan',
#   'location': '3 BHK Flat in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,707 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Hadinaru, Mysore',
#   'location': 'Residential land / Plot in Hadinaru, Mysore',
#   'price': '₹16 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Subramanya Nagar, Mysore',
#   'location': '2 Bedroom House in Subramanya Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '936 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Vyasti Urbane',
#   'location': 'Residential land / Plot in Vijayanagar, Mysore',
#   'price': '₹77 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nithyanandhasagara Layout Phase 1',
#   'location': 'Residential land / Plot in Huyilalu, Mysore',
#   'price': '₹57 Lac',
#   'area': '2,020 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'hari vidyalaya',
#   'location': '2 BHK Independent Builder Floor in Bogadi, Mysore',
#   'price': '₹73 Lac',
#   'area': '30 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'ESS Anandhasagara Layout',
#   'location': 'Residential land / Plot in Huyilalu, Mysore',
#   'price': '₹1 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Ilavala Hobli, Mysore',
#   'location': 'Residential land / Plot in Ilavala Hobli, Mysore',
#   'price': '₹19.5 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '4 Bedroom House in JP Nagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Owner Built',
#   'location': '3 Bedroom House in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹3.3 Cr',
#   'area': '2,325 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '5 BHK Independent Builder Floor in JP Nagar, Mysore',
#   'price': '₹1.95 Cr',
#   'area': '1,750 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Sankalp Gardenia',
#   'location': '2 BHK Flat in Gokulam, Mysore',
#   'price': '₹96 Lac',
#   'area': '1,385 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'KBL Silicon City\n3.6',
#   'location': 'Residential land / Plot in Hebbal, Mysore',
#   'price': '₹47 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Shakthinagar, Mysore',
#   'location': '3 Bedroom House in Shakthinagar, Mysore',
#   'price': '₹2.9 Cr',
#   'area': '5,500 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Close to NPS',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹85 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'K Hemmanahalli, Mysore',
#   'location': 'Residential land / Plot in K Hemmanahalli, Mysore',
#   'price': '₹35 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'hunsur maroad',
#   'location': '2 Bedroom House in Yelwala, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Police Layout, Mysore',
#   'location': '5 Bedroom House in Police Layout, Mysore',
#   'price': '₹1.3 Cr',
#   'area': '1,162 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Karakanahalli, Mysore',
#   'location': 'Residential land / Plot in Karakanahalli, Mysore',
#   'price': '₹1.2 Cr',
#   'area': '4,935 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Block 6',
#   'location': '2 Bedroom House in Sriramapura 2nd Stage, Mysore',
#   'price': '₹2.1 Cr',
#   'area': '1,953 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Shankara Nagar(Gayathri Layout), Dattagalli, 3rd stage, Mysore',
#   'location': 'Residential land / Plot in Shankara Nagar(Gayathri Layout), Dattagalli, 3rd stage, Mysore',
#   'price': '₹72 Lac',
#   'area': '1,470 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'teachers layout',
#   'location': 'Residential land / Plot in Teachers Layout 1st Stage, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '2,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Koppa, Mysore',
#   'location': '5 Bedroom House in Koppa, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '1,500 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'Nanjangud Road, Mysore',
#   'location': 'Residential land / Plot in Nanjangud Road, Mysore',
#   'price': '₹1.12 Cr',
#   'area': '60,983 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Vidyaranyapura, Mysore',
#   'location': '3 Bedroom House in Vidyaranyapura, Mysore',
#   'price': '₹1.15 Cr',
#   'area': '900 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Allanahalli Layout, Mysore',
#   'location': 'Residential land / Plot in Allanahalli Layout, Mysore',
# ...
#   'location': '6 Bedroom House in Bogadi 2nd Stage, Mysore',
#   'price': '₹3.2 Cr',
#   'area': '2,250 sqft',
#   'bhk': '6 BHK'},
#  {'name': '1st Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 1st Stage Vijayanagar, Mysore',
#   'price': '₹3.3 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'KBL Silicon City',
#   'location': 'Residential land / Plot in Hebbal, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹82 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RUDHYA ESTATES',
#   'location': 'Residential land / Plot in Ramakrishna Nagar, Mysore',
#   'price': '₹2.35 Cr',
#   'area': '2,818 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Police Layout, Mysore',
#   'location': 'Residential land / Plot in Police Layout, Mysore',
#   'price': '₹57 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '94 833 95 638',
#   'location': '5 Bedroom House in Vidyaranyapura, Mysore',
#   'price': '₹1.62 Cr',
#   'area': '2,430 sqft',
#   'bhk': '5 BHK'},
#  {'name': 'RUDHYA ESTATES',
#   'location': '4 Bedroom House in Dattagalli, Mysore',
#   'price': '₹1.85 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'K H B',
#   'location': 'Residential land / Plot in Ramachandra Agrahara, Mysore',
#   'price': '₹27 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'RUDHYA ESTATES',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹29.99 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bogadi, Mysore',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹16.5 Lac',
#   'area': '600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'On Saddle beat Adventure Road',
#   'location': 'Residential land / Plot in Mahadevpura Road, Mysore',
#   'price': '₹1.2 Cr',
#   'area': '9,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Next to Ahad City, Mysore',
#   'location': 'Residential land / Plot in Rajiv Nagar, Mysore',
#   'price': '₹85 Lac',
#   'area': '6,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Astrum Grandview Mysore Phase 1\n4.0',
#   'location': '3 BHK Flat in JP Nagar, Mysore',
#   'price': '₹75.25 Lac',
#   'area': '1,308 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Astrum Grandview Mysore Phase 1\n4.0',
#   'location': '2 BHK Flat in JP Nagar, Mysore',
#   'price': '₹65.25 Lac',
#   'area': '1,128 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹18.03 Lac',
#   'area': '1,163 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹18.61 Lac',
#   'area': '1,163 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Chamalapura',
#   'location': 'Residential land / Plot in Nanjangud, Mysore',
#   'price': '₹46.5 Lac',
#   'area': '1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Yelwala, Mysore',
#   'location': 'Residential land / Plot in Yelwala, Mysore',
#   'price': '₹28.49 Lac',
#   'area': '1,163 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Tirumakudalu Narasipura, Mysore',
#   'location': 'Residential land / Plot in Tirumakudalu Narasipura, Mysore',
#   'price': '₹40 Lac',
#   'area': '9,800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Vijay Nagar 2nd Stage, Mysore',
#   'location': '4 Bedroom House in Vijay Nagar 2nd Stage, Mysore',
#   'price': '₹2.1 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹90 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'JP Nagar 2nd Stage, Mysore',
#   'location': '2 Bedroom House in JP Nagar 2nd Stage, Mysore',
#   'price': '₹90 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'JP Nagar, Mysore',
#   'location': '2 Bedroom House in JP Nagar, Mysore',
#   'price': '₹95 Lac',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Dhatri Square.',
#   'location': 'Residential land / Plot in Ilavala Hobli, Mysore',
#   'price': '₹21.8 Lac',
#   'area': '1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Udbur, Mysore',
#   'location': 'Residential land / Plot in Udbur, Mysore',
#   'price': '₹37 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'University Layout, Mysore',
#   'location': 'Residential land / Plot in University Layout, Mysore',
#   'price': '₹66 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bogadi, Mysore',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹22 Lac',
#   'area': '800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'SUMHADAYI',
#   'location': 'Residential land / Plot in Jss Layout, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Chamundipuram, Mysore',
#   'location': '3 Bedroom House in Chamundipuram, Mysore',
#   'price': '₹4.9 Cr',
#   'area': '5,760 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'JSS Layout 2nd Stage, Mysore',
#   'location': '4 BHK Independent Builder Floor in JSS Layout 2nd Stage, Mysore',
#   'price': '₹85 Lac',
#   'area': '600 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Dattagalli, Mysore',
#   'location': '3 BHK Independent Builder Floor in Dattagalli, Mysore',
#   'price': '₹1.2 Cr',
#   'area': '1,200 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Sakthi Nagar, Mysore',
#   'location': '4 Bedroom House in Sakthi Nagar, Mysore',
#   'price': '₹1.55 Cr',
#   'area': '1,200 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Shanthaveri Gopal Gowda Nagar, Mysore',
#   'location': '2 Bedroom House in Shanthaveri Gopal Gowda Nagar, Mysore',
#   'price': '₹55 Lac',
#   'area': '600 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'The Eagles',
#   'location': '3 BHK Flat in Hebbal, Mysore',
#   'price': '₹85 Lac',
#   'area': '1,793 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'The Eagles',
#   'location': '3 BHK Flat in Yadavagiri, Mysore',
#   'price': '₹1.75 Cr',
#   'area': '2,450 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Police Layout, Mysore',
#   'location': 'Residential land / Plot in Police Layout, Mysore',
#   'price': '₹74 Lac',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bogadi Road, Mysore',
#   'location': 'Residential land / Plot in Bogadi Road, Mysore',
#   'price': '₹24.75 Lac',
#   'area': '900 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹65 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bogadi, Mysore',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹1.6 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'oxygen nesara',
#   'location': '2 BHK Flat in Hebbal, Mysore',
#   'price': '₹66 Lac',
#   'area': '1,250 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Sankalp Magnum',
#   'location': '3 BHK Flat in JP Nagar, Mysore',
#   'price': '₹80 Lac',
#   'area': '1,275 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': '2 Bedroom House in Srinagara Layout, Mysore',
#   'price': '₹62 Lac',
#   'area': '1,260 sqft',
#   'bhk': '2 BHK'},
#  {'name': '2nd Stage Vijay Nagar, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Vijay Nagar, Mysore',
#   'price': '₹2.35 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Lal Bahadur Shastri Nagar, Mysore',
#   'location': '3 Bedroom House in Lal Bahadur Shastri Nagar, Mysore',
#   'price': '₹78 Lac',
#   'area': '1,100 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Sankalp Magnum',
#   'location': '2 BHK Flat in JP Nagar, Mysore',
#   'price': '₹66 Lac',
#   'area': '900 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Sankalp Magnum',
#   'location': '3 BHK Flat in JP Nagar, Mysore',
#   'price': '₹77 Lac',
#   'area': '1,275 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Bogadi, Mysore',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹1.62 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hegde enclave',
#   'location': 'Residential land / Plot in Bannur Road, Mysore',
#   'price': '₹42 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Oxygen Courtyard',
#   'location': '2 BHK Flat in Dattagalli, Mysore',
#   'price': '₹70 Lac',
#   'area': '1,300 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'R R Layout',
#   'location': 'Residential land / Plot in Jayapura, Mysore',
#   'price': '₹17 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Manya Enclave',
#   'location': 'Residential land / Plot in Varuna, Mysore',
#   'price': '₹24 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Huyilalu, Mysore',
#   'location': 'Residential land / Plot in Huyilalu, Mysore',
#   'price': '₹49.8 Lac',
#   'area': '1,550 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '1st Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 1st Stage Vijayanagar, Mysore',
#   'price': '₹2.3 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hosahundi, Mysore',
#   'location': 'Residential land / Plot in Hosahundi, Mysore',
#   'price': '₹52.5 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bogadi, Mysore',
#   'location': 'Residential land / Plot in Bogadi, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '3,375 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Sardar Vallabh Bhai Patel Nagar, Mysore',
#   'location': 'Residential land / Plot in Sardar Vallabh Bhai Patel Nagar, Mysore',
#   'price': '₹60 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '1st Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 1st Stage Vijayanagar, Mysore',
#   'price': '₹2.3 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal 2nd Stage, Mysore',
#   'location': 'Residential land / Plot in Hebbal 2nd Stage, Mysore',
#   'price': '₹67 Lac',
#   'area': '1,900 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Kuvempunagara North, Mysore',
#   'location': '4 Bedroom House in Kuvempunagara North, Mysore',
#   'price': '₹3.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': '4 BHK'},
#  {'name': '3rd Stage Vijayanagar, Mysore',
#   'location': '4 Bedroom House in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹3.3 Cr',
#   'area': '2,400 sqft',
#   'bhk': '4 BHK'},
#  {'name': 'Hebbal 2nd Stage, Mysore',
#   'location': '2 Bedroom House in Hebbal 2nd Stage, Mysore',
#   'price': '₹1.8 Cr',
#   'area': '2,400 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.05 Cr',
#   'area': '2,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Sindhuvalli, Mysore',
#   'location': 'Residential land / Plot in Sindhuvalli, Mysore',
#   'price': '₹11.5 Lac',
#   'area': '899 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'ESS Sree Sapthamathruka Layout',
#   'location': 'Residential land / Plot in Tirumakudalu Narasipura, Mysore',
#   'price': '₹20 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'ESS Sree Sapthamathruka Layout',
#   'location': 'Residential land / Plot in Tirumakudalu Narasipura, Mysore',
#   'price': '₹52 Lac',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Premio by BVL Group',
#   'location': 'Residential land / Plot in Choranahalli, Mysore',
#   'price': '₹65.99 Lac',
#   'area': '1,453 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Jayalakshmipuram, Mysore',
#   'location': 'Residential land / Plot in Jayalakshmipuram, Mysore',
#   'price': '₹3.1 Cr',
#   'area': '2,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '3rd Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹1.68 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Dattagalli 3rd Stage, Mysore',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹1.02 Cr',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.25 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Roopa Nagar, Mysore',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.1 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Premio by BVL Group',
#   'location': 'Residential land / Plot in Choranahalli, Mysore',
#   'price': '₹60 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '94833 95638',
#   'location': 'Residential land / Plot in Roopa Nagar, Mysore',
#   'price': '₹1.65 Cr',
#   'area': '4,000 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Astrum Grandview Mysore Phase 1\n4.0',
#   'location': '3 BHK Flat in JP Nagar, Mysore',
#   'price': '₹75.2 Lac',
#   'area': '1,308 sqft',
#   'bhk': '3 BHK'},
#  {'name': '1st Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 1st Stage Vijayanagar, Mysore',
#   'price': '₹2 Cr',
#   'area': '1,800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Srinagara Layout, Mysore',
#   'location': 'Residential land / Plot in Srinagara Layout, Mysore',
#   'price': '₹49 Lac',
#   'area': '1,050 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Dattagalli, Mysore',
#   'location': '3 Bedroom House in Dattagalli, Mysore',
#   'price': '₹1.65 Cr',
#   'area': '1,440 sqft',
#   'bhk': '3 BHK'},
#  {'name': '2nd Stage Gokulam, Mysore',
#   'location': 'Residential land / Plot in 2nd Stage Gokulam, Mysore',
#   'price': '₹3 Cr',
#   'area': '2,600 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹90 Lac',
#   'area': '1,800 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '3rd Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 3rd Stage Vijayanagar, Mysore',
#   'price': '₹2 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Hebbal 2nd Stage, Mysore',
#   'location': '2 Bedroom House in Hebbal 2nd Stage, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '1,200 sqft',
#   'bhk': '2 BHK'},
#  {'name': '4th Stage Vijayanagar, Mysore',
#   'location': 'Residential land / Plot in 4th Stage Vijayanagar, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'BOGADHI RAILWAY LAYOUT, Mysore',
#   'location': 'Residential land / Plot in BOGADHI RAILWAY LAYOUT, Mysore',
#   'price': '₹1.5 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Premio by BVL Group',
#   'location': 'Residential land / Plot in Choranahalli, Mysore',
#   'price': '₹50.5 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'THE EAGLES',
#   'location': '3 BHK Flat in Vishweshwara Nagar , Mysore',
#   'price': '₹80 Lac',
#   'area': '1,840 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'Kuvempunagar, Mysore',
#   'location': '3 BHK Independent Builder Floor in Kuvempunagar, Mysore',
#   'price': '₹2.1 Cr',
#   'area': '3,500 sqft',
#   'bhk': '3 BHK'},
#  {'name': 'The eagles',
#   'location': '2 BHK Flat in Yadavagiri, Mysore',
#   'price': '₹80 Lac',
#   'area': '1,175 sqft',
#   'bhk': '2 BHK'},
#  {'name': 'Dattagalli, Mysore',
#   'location': 'Residential land / Plot in Dattagalli, Mysore',
#   'price': '₹2.05 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Dattagalli 3rd Stage, Mysore',
#   'location': 'Residential land / Plot in Dattagalli 3rd Stage, Mysore',
#   'price': '₹79 Lac',
#   'area': '1,200 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': '3rd Stage Sriramapura, Mysore',
#   'location': 'Residential land / Plot in 3rd Stage Sriramapura, Mysore',
#   'price': '₹75 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Treasury layout, Mysore',
#   'location': 'Residential land / Plot in Treasury layout, Mysore',
#   'price': '₹87 Lac',
#   'area': '1,500 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Nivedita Nagar, Mysore',
#   'location': 'Residential land / Plot in Nivedita Nagar, Mysore',
#   'price': '₹1.86 Cr',
#   'area': '2,400 sqft',
#   'bhk': 'Plot/Land'},
#  {'name': 'Bogadi, Mysore',
#   'location': '6 Bedroom House in Bogadi, Mysore',
#   'price': '₹1 Cr',
#   'area': '600 sqft',
#   'bhk': '6 BHK'},
#  ...]

# %% [markdown]
# ### Exporting the scraped data

# %%
raw_df = pd.DataFrame(data)

# %%
raw_df.to_csv('raw_mysuru.csv')
